# %% [markdown]
# # Impacto de la Inteligencia Artificial en el Mercado Laboral de América Latina (2020-2025)
#
# **DOI:** https://doi.org/10.5281/zenodo.19211331
# **Autor:** de la Serna, Juan Moisés
# **Año:** 2025

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

print("Análisis: Impacto IA en Mercado Laboral LATAM")

# %% [markdown]
# ## 1. Carga de datos
#
# Cargamos los 4 archivos CSV del dataset.

# %%
# df_automatizacion = pd.read_csv("automatizacion_sectores.csv")
# df_desplazamiento = pd.read_csv("desplazamiento_laboral.csv")
# df_ocupaciones = pd.read_csv("nuevas_ocupaciones.csv")
# df_politicas = pd.read_csv("politicas_laborales.csv")

# %% [markdown]
# ## 2. Análisis de automatización por sector
#
# Visualizamos los sectores con mayor riesgo de automatización.

# %%
# Visualización: sectores con mayor automatización
# df_automatizacion.sort_values("indice_automatizacion", ascending=False).head(10).plot(kind="bar", x="sector")
# plt.title("Top 10 sectores con mayor riesgo de automatización")
# plt.show()

# %% [markdown]
# ## Cómo citar
#
# ```
# de la Serna, Juan Moisés (2025). Impacto de la Inteligencia Artificial en el Mercado Laboral de América Latina (2020-2025). Zenodo. https://doi.org/10.5281/zenodo.19211331
# ```
